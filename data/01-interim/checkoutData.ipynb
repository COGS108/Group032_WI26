# %%
import seaborn as sns
sns.set(font_scale=2, style="white")

import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.style as style
# set plotting size parameter
plt.rcParams['figure.figsize'] = (17, 7)

# import pandas & numpy library
import pandas as pd
import numpy as np
import scipy.stats as stats

# Statmodels
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import seaborn as sns
#       2 sns.set(font_scale=2, style="white")
#       4 import matplotlib
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df_FL_Benthic_Cover = pd.read_csv("data\00-raw\CRCP_Benthic_Cover_Florida_7018_0ee5_9488.csv")

df_PR_Benthic_Cover = pd.read_csv("data\00-raw\CRCP_Benthic_Cover_Puerto_Rico_07c6_3c17_78b6.csv")

df_USVI_Benthic_Cover = pd.read_csv("data\00-raw\CRCP_Benthic_Cover_USVI_6400_ac60_8c98.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# <>:5: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# <>:5: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\julia\AppData\Local\Temp\ipykernel_37872\1252185910.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df_FL_Benthic_Cover = pd.read_csv("data\00-raw\CRCP_Benthic_Cover_Florida_7018_0ee5_9488.csv")
# C:\Users\julia\AppData\Local\Temp\ipykernel_37872\1252185910.py:3: SyntaxWarning: invalid escape sequence '\C'
#   df_PR_Benthic_Cover = pd.read_csv("data\00-raw\CRCP_Benthic_Cover_Puerto_Rico_07c6_3c17_78b6.csv")
# C:\Users\julia\AppData\Local\Temp\ipykernel_37872\1252185910.py:5: SyntaxWarning: invalid escape sequence '\C'
#   df_USVI_Benthic_Cover = pd.read_csv("data\00-raw\CRCP_Benthic_Cover_USVI_6400_ac60_8c98.csv")
# ...

# %%
df_FL_Benthic_Cover.head()

df_FL_Benthic_Cover.columns

df_FL_Benthic_Cover.describe()
