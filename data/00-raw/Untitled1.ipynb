# %%
import pandas as pd

# %%
pr = pd.read_csv('CRCP_Benthic_Cover_Puerto_Rico_07c6_3c17_78b6.csv')

# %%
pr['YEAR'].unique()
# Out:
# array([  nan, 2019., 2016., 2021., 2017., 2014., 2023.])

# %%
fl = pd.read_csv('CRCP_Benthic_Cover_Puerto_Rico_07c6_3c17_78b6.csv')

# %%
fl['YEAR'].unique()
# Out:
# array([  nan, 2019., 2016., 2021., 2017., 2014., 2023.])
