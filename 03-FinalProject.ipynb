# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Alice Anderson: Conceptualization, Data curation, Methodology, Writing - original draft
# - Bob Barker:  Analysis, Software, Visualization
# - Charlie Chang: Project administration, Software, Writing - review & editing
# - Dani Delgado: Analysis, Background research, Visualization, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# Since the 2016 mass coral bleaching event, what distinct recovery trajectories in percent live coral cover are observed across U.S. Caribbean coral reef sites during 2016-2020 (a four-year recovery window in two intervals of two years each), and how are cumulative thermal stress and mean algal cover associated with these different recovery pathways?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Coral reefs are highly sensitive marine ecosystems that provide important ecological, economic, and coastal protection benefits. In recent years, coral reef health has declined worldwide due to rising sea surface temperatures, more frequent marine heatwaves, and local stressors such as algal overgrowth. Thermal stress, often measured using Degree Heating Weeks (DHW), is strongly linked to coral bleaching events, which can lead to partial or complete loss of live coral cover. <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) While many studies document coral decline following thermal stress, less is known about how coral reefs recover over time and weather recovery follows consistent patterns across different sites.  <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)
#
# Being students of University of California, San Diego, part of our academic environment is ingrained with the university’s strengths in marine biology, oceanography, and climate science through programs such as the Scripps Institution of Oceanography. UC San Diego researchers have made major contributions to coral reef monitoring and the study of climate-driven marine stressors, which does add to the motivation for this project. Publicly available datasets from organizations like NOAA and the National Coral Reef Monitoring Program align well with UC San Diego’s emphasis on data-driven marine science and provide a strong foundation for this analysis.
#
# Previous research has shown that coral recovery trajectories can vary widely depending on environmental conditions and local ecological dynamics. Studies using NOAA Coral Reef Watch data have found that higher DHW values are associated with more severe bleaching and increased coral mortality, often resulting in slow or incomplete recovery. <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) However, more recent monitoring efforts, such as the National Coral Reef Monitoring Program (NCRMP), provide long-term, site-level data on percent live coral and algal cover across U.S. reef systems. <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)
#
# While many studies using these data focus on overall trends in reef health, fewer explicitly examine differences in recovery pathways over time. Our project builds on this prior work by identifying coral recovery trajectories and analyzing how thermal stress and algal cover, both individually and together, are associated with differences in recovery outcomes across U.S. coral reef sites.
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Watch, N. C. R. (n.d.). Coral Reef Watch Home. NOAA Coral Reef Watch Daily 5km Satellite Coral Bleaching Heat Stress Monitoring Products (Version 3.1). https://coralreefwatch.noaa.gov/product/5km/index.php
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Hughes et Al. (2017, March 16). Global warming and recurrent mass bleaching of corals. Nature News. https://www.nature.com/articles/nature21707
# 3. <a name="cite_note-3"></a> [^](#cite-ref-3)Liu, G. et Al. (2014, November 20). Reef-scale thermal stress monitoring of coral ecosystems: New 5-km global products from NOAA Coral Reef Watch. MDPI. https://www.mdpi.com/2072-4292/6/11/11579
# 4. <a name="cite_note-4"></a> [^](#cite-ref-4)National Coral Reef Monitoring Program: Tracking Environmental Conditions. NCRMP | Environmental. (n.d.). https://coralreef.noaa.gov/topics/national-coral-reef-monitoring-program/environmental

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that coral reef sites exposed to higher cumulative thermal stress will exhibit recovery trajectories characterized by slower increases or sustained declines in percent live coral cover. Higher cumulative thermal stress is strongly associated with coral bleaching, reduced repoduction, and decline in health, which can all prevent reef recovery. We also predict that sites with higher algal cover will show poorer recovery outcomes. Elevated algal cover often follows coral loss and can also prove to be detrimental to coral by competing for space and changing the conditions in the area.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback.

# %% [markdown]
# ### Dataset #1 Florida NCRMP Benthic Cover Data
#
# This dataset contains benthic cover observations from Florida reef monitoring sites collected under the National Coral Reef Monitoring Program (NCRMP).
#
# The dataset includes 13,602 observations and 35 variables. Important variables for our analysis include:
#
# - PRIMARY_SAMPLE_UNIT: Unique reef site identifier
# - LATITUDE and LONGITUDE: Geographic coordinates used to match sites to thermal grid data
# - YEAR: Survey year
# - REGION: Geographic region classification
# - COVER_CAT_NAME: Organism category (coral vs algae)
# - HARDBOTTOM_P: Percent hardbottom cover (used to compute total coral and algae percentages)
#
# Percent cover values represent the proportion of reef surface covered by different organism categories.
#
# One limitation of this dataset is uneven monitoring across sites and missing values in certain habitat and substrate variables.

# %%
florida = pd.read_csv("data/00-raw/CRCP_Benthic_Cover_Florida_7018_0ee5_9488.csv")

print(florida.shape)
florida.head()
florida.isnull().sum()

# %%
florida.columns

# %%
cols_needed = [
    "PRIMARY_SAMPLE_UNIT",
    "latitude",
    "longitude",
    "YEAR",
    "REGION",
    "COVER_CAT_NAME",
    "HARDBOTTOM_P"
]

florida_clean = florida[cols_needed].copy()

florida_clean["HARDBOTTOM_P"] = pd.to_numeric(
    florida_clean["HARDBOTTOM_P"],
    errors="coerce"
)

florida_clean.head()

# %%
florida_clean.shape

# %%
florida_clean.isnull().sum()

# %%
florida_clean["COVER_CAT_NAME"].unique()

# %%
def classify_group(cat):

    coral = [
        "Hard Coral",
        "Soft Coral"
    ]

    algae = [
        "Macroalgae",
        "Turf Algae",
        "CCA",
        "Crustose Coralline Algae"
    ]

    if cat in coral:
        return "Coral"
    elif cat in algae:
        return "Algae"
    else:
        return "Other"

# %%
florida_clean["group"] = florida_clean["COVER_CAT_NAME"].apply(classify_group)

# %%
florida_clean.to_csv("data/02-processed/benthic_cover_FL_cleaned.csv", index=False)

# %% [markdown]
# ### Dataset #2 Puerto Rico Coral Reef Benthic Cover (CRCP Monitoring Data, 2014-2023)
#
# The Puerto Rico Benthic Cover dataset includes 10,656 reef survey observations collected between 2014 and 2023 through NOAA’s Coral Reef Conservation Program. Each row represents one benthic category (like live coral or algae) measured at a specific reef site on a particular survey date. The dataset includes the site ID (`PRIMARY_SAMPLE_UNIT`), latitude and longitude (in decimal degrees), survey year (and month/day when available), region, the organism category (`COVER_CAT_NAME`), and the percent of hardbottom covered (`HARDBOTTOM_P`).
#
# The main variable we care about is percent hardbottom cover, which is measured in percent (%). This tells us how much of the reef surface is covered by a certain organism type. For example, 30% live coral cover means that about one-third of the surveyed reef area was covered by living coral. In many reef systems, coral cover above about 30% is considered relatively healthy, while values below 10% often suggest significant degradation or limited recovery after stress events.
#
# Since our research question looks at recovery patterns in live coral cover and how those patterns relate to algal cover, we use COVER_CAT_NAME to separate coral from algae and HARDBOTTOM_P to measure how dominant each group is. By combining location (site and region) with time (year), we can track how coral cover changes over time at different sites and see whether some reefs recover differently than others. This helps us explore whether higher algal cover is associated with weaker coral recovery after stress events.
#
# **Variables We're Focusing On**
#
# For this analysis, we’re mainly looking at location and habitat structure variables from the benthic dataset.
# * Site ID (`PRIMARY_SAMPLE_UNIT`)
# This is the unique identifier for each survey site. It allows us to group observations by location and track changes over time at the same site
# * Latitude (degrees north) and Longitude (degrees east)
# These tell us where each survey site is located. We’ll use them to look at spatial patterns and see whether habitat characteristics cluster in certain areas.
# * Date (`YEAR`, `MONTH`, `DAY`)
# These variables describe when the observation was recorded. YEAR allows us to evaluate long-term trends, while month/day could help identify seasonal patterns.
# * Region
# This categorizes sites into broader geographic areas within Puerto Rico. It allows us to compare coral and algae cover across different parts of the island.
# * `COVER_CAT_NAME`
# This identifies the organism category being measured (e.g., coral, algae). This is central to our research question because we are specifically comparing coral vs. algae cover.
# * Percent Cover (`HARDBOTTOM_P`)
# This is the key outcome variable. It represents the percentage of hardbottom substrate covered by the organism listed in `COVER_CAT_NAME`.
# It is measured as a percent (%), ranging theoretically from 0 to 100.
# > * Values near 0% indicate little to no coverage.
# > * Values near 100% indicate nearly complete coverage of the hardbottom area by that organism type.
# > * Values outside 0–100% would be biologically impossible and indicate data issues.
#
# By combining site location (latitude and longitude), region, time (year, month, day), organism category (coral vs. algae), and percent hardbottom cover, we can analyze how benthic community composition varies across Puerto Rico and over time. These variables allow us to examine both spatial differences between regions and temporal trends within sites. Rather than simply describing individual survey locations, this approach helps us identify broader patterns in coral and algae cover and assess how benthic communities may be shifting across space and time.
#
#
# **Concerns and Limitations**
#
# One major concern is sampling bias. Survey sites are not randomly distributed across all reef habitat — they are likely chosen based on accessibility, monitoring priorities, or ecological importance. This means results may not represent all reef areas equally.
#
# Another limitation is temporal imbalance. Some sites may have been surveyed more frequently than others, and some years may have more complete coverage than others. This could affect trend analysis.
#
# In addition, several numeric variables (like latitude, depth, and percent cover values) are stored as text and need to be converted before analysis. The first row of the dataset also contains unit labels instead of real data and must be removed during cleaning.
#
# Finally, the dataset only covers about 10 years (2014–2023), not the full 20-year period in our research question. While it still captures recent bleaching and stress events, longer-term trends would require additional historical data.

# %%
benthic_PR = pd.read_csv("data/00-raw/CRCP_Benthic_Cover_Puerto_Rico_07c6_3c17_78b6.csv")

benthic_PR.head()

# %%
benthic_PR.shape

# %%
benthic_PR.columns

# %%
cols_to_keep = [
    "PRIMARY_SAMPLE_UNIT",
    "latitude",
    "longitude",
    "YEAR",
    "MONTH",
    "DAY",
    "REGION",
    "COVER_CAT_NAME",
    "HARDBOTTOM_P"
]

benthic_PR = benthic_PR[[col for col in cols_to_keep if col in benthic_PR.columns]]

# %%
benthic_PR.head()

# %%
benthic_PR["YEAR"].value_counts().sort_index()

# %% [markdown]
# **Check Tidy Structure**
#
# The dataset is already in long (tidy) format because each row represents one benthic category observation at a specific site and date. Each column represents a single variable (e.g., depth, percent cover, region).
# **_BUT_**, this does not mean it is *clean*.

# %%
benthic_PR.info()

# %%
print("Number of rows:", benthic_PR.shape[0])
print("Number of columns:", benthic_PR.shape[1])

# %%
## Convert Data Types

numeric_cols = [
    "latitude",
    "longitude",
    "YEAR",
    "MONTH", 
    "DAY",
    "HARDBOTTOM_P"
]

for col in numeric_cols:
    benthic_PR[col] = pd.to_numeric(benthic_PR[col], errors="coerce")

# %%
## Missing Data Analysis

missing_counts = benthic_PR.isna().sum()
missing_percent = benthic_PR.isna().mean() * 100

pd.DataFrame({
    "Missing Count": missing_counts,
    "Missing %": missing_percent
}).sort_values("Missing %", ascending=False)

# %%
outliers = benthic_PR[
    (benthic_PR["HARDBOTTOM_P"] < 0) |
    (benthic_PR["HARDBOTTOM_P"] > 100)
]

outliers

# %% [markdown]
# No biologically impossible percent values (<0% or >100%) were seen.

# %%
benthic_PR["HARDBOTTOM_P"].describe()

# %% [markdown]
# **Cleaning Strategy**
#
# Columns that are entirely missing/ not being used for our research question (e.g., ZONE_NAME, MPA_NAME, PROT) are going to be dropped because they contain no usable information (as done above). Numeric variables stored as text were converted to numeric format. (also done above)
#
# Because HARDBOTTOM_P is our primary outcome variable, rows missing this value cannot be used for analysis and will be removed.
# We also drop rows missing essential identifiers (site, year, region, category).
#
# *We keep rows with missing MONTH or DAY if YEAR is present, since yearly trends are sufficient for our main analysis.*

# %%
benthic_clean_PR = benthic_PR.dropna(
    subset=[
        "PRIMARY_SAMPLE_UNIT",
        "YEAR",
        "REGION",
        "COVER_CAT_NAME",
        "HARDBOTTOM_P"
    ]
)

# %%
benthic_clean_PR.to_csv("data/02-processed/benthic_cover_PR_cleaned.csv", index=False)

# %% [markdown]
# ### Dataset #3 U.S. Virgin Islands Benthic Habitat Percent Cover Dataset
#
# This dataset contains benthic habitat percent cover observations from U.S. Virgin Islands reef monitoring sites.
#
# Link to dataset: https://github.com/COGS108/Group032_WI26/blob/master/data/00-raw/CRCP_Benthic_Cover_USVI_6400_ac60_8c98.csv
#
# The dataset includes 26,325 observations and 7 variables.
#
# **Important variables for our analysis include:**
# * PRIMARY_SAMPLE_UNIT: Unique reef site identifier
# * LATITUDE and LONGITUDE: Geographic coordinates used to locate sites
# * YEAR: Survey year
# * REGION: Island or area classification
# * COVER_CAT_NAME: Habitat category (e.g., coral, algae)
# * HARDBOTTOM_P: Percent cover value for hardbottom habitats
#
# These measurements matter because they describe relative dominance rather than exact quantities. A percent value does not tell us the total amount of coral or algae in an absolute sense,but it shows how much space each category occupies compared to others at that site and year. Looking at these values across multiple years helps reveal patterns of change over time.
#
# **Limitations to consider:**
# The monitoring sites were not selected randomly; they reflect locations that are accessible to researchers or part of established survey programs. As a result, some regions may be sampled more frequently than others. Because benthic cover is visually estimated by divers, environmental conditions and observer judgment can introduce some variability. The dataset also required minor cleaning before analysis, such as removing non-data rows. Even with these limitations, the dataset provides structured, site-specific information that allows for meaningful comparisons across space and time.

# %%
#load the dataset

df = pd.read_csv("data/00-raw/CRCP_Benthic_Cover_USVI_6400_ac60_8c98.csv", low_memory=False)

# %%
#make the dataset tidy or demonstrate that it was already tidy

#in the csv we can see that row 1 is a 'unit' row and can be confused with data
if pd.isna(pd.to_numeric(df.loc[0, "YEAR"], errors="coerce")):
    df = df.drop(index=0).reset_index(drop=True)
    #pd.isna(True or False) , if coerced to NaN, returns true, and if statement continues

print("duplicate rows:", df.duplicated().sum())

# %%
#demonstrate the size of the dataset
#only keep columns needed for analysis

columns_to_analyze = [
    "PRIMARY_SAMPLE_UNIT",
    "latitude",
    "longitude",
    "YEAR",
    "REGION",
    "COVER_CAT_NAME",
    "HARDBOTTOM_P"
]

df = df[columns_to_analyze]

print("Dataset shape after filtering columns:", df.shape)

# %%
#find out how much data is missing, 
#where its missing, 
#and if its missing at random 
#or seems to have any systematic relationships in its missingness

missing_summary = (
    df.isna()
      .agg(['sum', 'mean']) 
    #sum- calculates sum of True NaN #mean- proportion of True NaN
      .T
    #transposes table for readability
      .rename(columns={'sum': 'Missing_Count', 'mean': 'Missing_Percent'})
)

missing_summary['Missing_Percent'] *= 100
#converts proportion to percent
missing_summary = missing_summary.sort_values('Missing_Percent', ascending=False)
#sorts from most missing to least missing

print("\nMissing Data Summary:")
print(missing_summary)

#systematic missing?

great_missing = missing_summary[missing_summary['Missing_Percent'] > 20].index
numeric_df = df.select_dtypes(include='number')

for column in great_missing:
    print(f"\nMissingness correlations for {column}:")
    print(numeric_df.corrwith(df[column].isna().astype(int)).dropna())

# %%
#find and flag any outliers or suspicious entries
numeric_cols = df.select_dtypes(include='number').columns

def count_outliers(col):
    Q1 = col.quantile(0.25)
    Q3 = col.quantile(0.75)
    IQR = Q3 - Q1
    return ((col < Q1 - 1.5 * IQR) | (col > Q3 + 1.5 * IQR)).sum()

outlier_counts = df[numeric_cols].apply(count_outliers)
print(outlier_counts)

# %%
df.to_csv("data/02-processed/benthic_cover_USVI_cleaned.csv", index=False)

# %% [markdown]
# ### Dataset #4 Thermal Data
# # *THIS NEEDS TO BE ADDED*

# %% [markdown]
# ---
# ## Merging datasets
# In order to merge thermal data with the benthic data which contains exact reef locations, we would use nearest neighbor spatial matching. After aggregating all thermal data by site and year, for each benthic site observation we would extract all thermal grid points for that year and calculate distance from benthic site to each thermal grid point. Then, we will select the thermal grid point with the minimum distance. From the exact grid point, we will extract the DHW values and assign it to benthic site for that year.

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your EDA feedback
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
from sklearn.neighbors import BallTree

# %% [markdown]
# ### Section 1 of EDA - Analysis-Ready Site-Year Dataset
#
# Tasks:
# * Load fully processed datasets from: data/02-processed/
# * Filter benthic categories into:
#     * Coral
#     * Algae
# * Group by:  PRIMARY_SAMPLE_UNIT + YEAR
# * Compute: total_coral_cover AND total_algae_cover

# %% [markdown]
# ### Coral Recovery Trends Over Time
#
# This analysis examines how coral cover has changed over time across reef sites.
# By analyzing yearly averages of coral cover, we can observe whether coral reefs
# are recovering after bleaching events or continuing to decline.
#
# Understanding these trends helps identify whether reef ecosystems are resilient
# to thermal stress or if long-term degradation is occurring.

# %%
## Load fully processed datasets

florida_benthic = pd.read_csv("data/02-processed/benthic_cover_FL_cleaned.csv")
puerto_rico_benthic = pd.read_csv("data/02-processed/benthic_cover_PR_cleaned.csv")
usvi_benthic = pd.read_csv("data/02-processed/benthic_cover_USVI_cleaned.csv")
thermal_data = pd.read_csv("data/00-raw/thermal_caribbean_2016_2018_2020_PROCESSED.csv")

# %%
CORAL_SPECIES = {
    # Individual coral species
    "Eusmilia fastigiata", "Meandrina meandrites", "Orbicella faveolata",
    "Siderastrea siderea", "Stephanocoenia intersepta", "Millepora spp",
    "Dichocoenia stokesii", "Scolymia spp", "Montastraea cavernosa",
    "Colpophyllia natans", "Siderastrea radians", "Pseudodiploria strigosa",
    "Porites astreoides", "Diploria labyrinthiformis", "Orbicella annularis",
    "Agaricia agaricites", "Mycetophyllia lamarckiana", "Oculina robusta",
    "Mussa angulosa", "Porites porites", "Mycetophyllia aliciae",
    "Scolymia cubensis", "Acropora cervicornis", "Porites divaricata",
    "Solenastrea bournoni", "Siderastrea spp", "Madracis decactis",
    "Agaricia spp", "Porites spp", "Solenastrea spp", "Orbicella franksi",
    "Agaricia lamarcki", "Other coral", "Dendrogyra cylindrus",
    "Agaricia humilis", "Agaricia fragilis", "Favia fragum", "Meandrina spp",
    "Diploria spp.", "Colpophyllia spp", "Mycetophyllia ferox",
    "Helioceris cucullata", "Oculina diffusa", "Pseudodiploria clivosa",
    "Manicina areolata", "Madracis auretenra", "Madracis spp",
    "Porites furcata", "Madracis formosa", "Madracis carmabi",
    "Isophyllia sinuosa", "Acropora palmata",
}

ALGAE_SPECIES = {
    "Turf Algae with Sediment", "Turf Algae Free of Sediment",
    "Dictyota spp", "MacroOtherFleshy", "Lobophora spp",
    "Cyanophyta spp", "Peysonnellia", "Halimeda spp",
    "MacroOtherCalcareous", "Ramicrusta spp", "Rhodophyta cru. spp",
    "Magnoliophyta spp",
}

# %%
## Filter to Relevant Categories (Coral and Algae)

# Function to classify categories
def classify_category(cat_name):
    if pd.isna(cat_name):
        return None
    cat = cat_name.strip()
    # Pass 1: exact match
    if cat in CORAL_SPECIES:
        return "Coral"
    if cat in ALGAE_SPECIES:
        return "Algae"
    # Pass 2: substring on uppercase
    upper = cat.upper()
    coral_keywords = ["CORAL", "STONY CORAL", "SCL CORAL", "LIVE CORAL"]
    algae_keywords = ["ALGAE", "MACROALG", "TURF", "CYANO", "HALIMEDA",
                      "DICTYOTA", "LOBOPHORA", "RAMICRUSTA", "RHODOPHYTA",
                      "PEYSSONNELIA", "PEYSONNELLIA"]
    if any(kw in upper for kw in coral_keywords):
        return "Coral"
    if any(kw in upper for kw in algae_keywords):
        return "Algae"
    return None

# Apply classification
for df, name in [(florida_benthic, "Florida"),
                 (puerto_rico_benthic, "Puerto Rico"),
                 (usvi_benthic, "USVI")]:
    df["group"] = df["COVER_CAT_NAME"].apply(classify_category)
    coral_n = (df["group"] == "Coral").sum()
    algae_n = (df["group"] == "Algae").sum()
    total   = len(df)
    print(f"{name}: {coral_n} coral rows, {algae_n} algae rows "
          f"({100*(coral_n+algae_n)/total:.1f}% of total classified)")

# %% [markdown]
# We now have only the rows that are useful for analyzing coral vs. algal percent cover.

# %%
## Aggregate by Site and Year

def aggregate_site_year(df):
    df = df[df['group'].isin(['Coral', 'Algae'])].copy()

    site_agg = df.groupby(
        ['PRIMARY_SAMPLE_UNIT', 'YEAR', 'group']
    ).agg(
        HARDBOTTOM_P=('HARDBOTTOM_P', 'mean'),
        latitude=('latitude', 'first'),
        longitude=('longitude', 'first'),
        REGION=('REGION', 'first'),
    ).reset_index()

    pivoted = site_agg.pivot_table(
        index=['PRIMARY_SAMPLE_UNIT', 'YEAR', 'latitude', 'longitude', 'REGION'],
        columns='group',
        values='HARDBOTTOM_P',
        fill_value=0
    ).reset_index()

    pivoted.columns.name = None
    pivoted = pivoted.rename(columns={
        'Coral': 'total_coral_cover',
        'Algae': 'total_algae_cover'
    })
    return pivoted
    
florida_site_year     = aggregate_site_year(florida_benthic)
puerto_rico_site_year = aggregate_site_year(puerto_rico_benthic)
usvi_site_year        = aggregate_site_year(usvi_benthic)

site_year_cover = pd.concat(
    [florida_site_year, puerto_rico_site_year, usvi_site_year],
    ignore_index=True,
)

print(f"\nFinal dataset shape: {site_year_cover.shape}")
print(f"Years covered: {sorted(site_year_cover['YEAR'].dropna().astype(int).unique())}")
print(f"Regions: {site_year_cover['REGION'].unique()}")
print(f"\nCoral cover stats:\n{site_year_cover['total_coral_cover'].describe().round(2)}")
print(f"\nAlgae cover stats:\n{site_year_cover['total_algae_cover'].describe().round(2)}")
site_year_cover.head()

# %% [markdown]
# This table now has one row per site-year, showing the total coral and algae cover, along with latitude, longitude, and region. This is exactly what the other team members need for their EDA.

# %%
## Sanity Checks
# Check for biologically impossible values (cover > 100% or < 0%)
coral_out = (site_year_cover["total_coral_cover"] > 100).sum()
algae_out = (site_year_cover["total_algae_cover"] > 100).sum()
neg_coral = (site_year_cover["total_coral_cover"] < 0).sum()
neg_algae = (site_year_cover["total_algae_cover"] < 0).sum()

print(f"Coral cover > 100%: {coral_out}  |  Algae cover > 100%: {algae_out}")
print(f"Negative coral: {neg_coral}  |  Negative algae: {neg_algae}")

# Check for missing lat/lon
print(f"\nMissing lat: {site_year_cover['latitude'].isna().sum()}")
print(f"Missing lon: {site_year_cover['longitude'].isna().sum()}")
print(f"Missing YEAR: {site_year_cover['YEAR'].isna().sum()}")

# %%
## Save to interim file
import os
os.makedirs("data/01-interim", exist_ok=True)
site_year_cover.to_csv("data/01-interim/site_year_cover.csv", index=False)
print("Saved → data/01-interim/site_year_cover.csv")

# %% [markdown]
# #### Adding the Thermal Data

# %%
reef = site_year_cover.copy()
thermal = thermal_data.copy()

# %%
# Drop any rows where conversion failed
reef = reef.dropna(subset=['latitude', 'longitude'])
thermal = thermal.dropna(subset=['latitude', 'longitude'])

reef['latitude'] = pd.to_numeric(reef['latitude'], errors='coerce')
reef['longitude'] = pd.to_numeric(reef['longitude'], errors='coerce')
thermal['latitude'] = pd.to_numeric(thermal['latitude'], errors='coerce')
thermal['longitude'] = pd.to_numeric(thermal['longitude'], errors='coerce')

# Build a BallTree on thermal grid coordinates (in radians for haversine)
thermal_coords = np.radians(thermal[['latitude', 'longitude']].values)
tree = BallTree(thermal_coords, metric='haversine')

# Find nearest thermal grid point for each reef site
reef_coords = np.radians(reef[['latitude', 'longitude']].values)
distances, indices = tree.query(reef_coords, k=1)

# Attach the nearest thermal grid index to each reef row
reef['thermal_idx'] = indices.flatten()
thermal['thermal_idx'] = range(len(thermal))

# %%
# Merge reef sites with their nearest thermal grid point
reef = reef.merge(
    thermal[['thermal_idx', 'year', 'annual_dhw']],
    left_on=['thermal_idx', 'YEAR'],
    right_on=['thermal_idx', 'year'],
    how='left'
).drop(columns=['thermal_idx', 'year'])

site_year_thermal_cover = reef

# %%
## Save to interim file
os.makedirs("data/01-interim", exist_ok=True)
site_year_thermal_cover.to_csv("data/01-interim/site_year_thermal_cover.csv", index=False)
print("Saved → data/01-interim/site_year_thermal_cover.csv")

# %%
## Histogram of total coral cover

plt.figure(figsize=(8,5))

sns.histplot(
    site_year_cover['total_coral_cover'],
    bins=30,
    kde=False,
    color='coral'
)

plt.xlabel("Total Coral % Cover")
plt.ylabel("Number of Site-Year Observations")
plt.title("Distribution of Coral Cover Across Sites")

plt.show()

# %% [markdown]
# Shows how many site-year observations fall into each coral cover range. Peaks at low values (0–10%) suggest many stressed or degraded reefs, while higher values (20–40%+) indicate healthier sites. This helps us see variability in coral recovery potential across sites and years.

# %%
## Histogram of total algae cover

plt.figure(figsize=(8,5))
sns.histplot(site_year_cover['total_algae_cover'], bins=30, kde=False, color='green')
plt.xlabel("Total Algae % Cover")
plt.ylabel("Number of Site-Year Observations")
plt.title("Distribution of Total Algae Cover Across All Sites and Years")
plt.show()

# %% [markdown]
# Displays the distribution of algal cover percentages across sites and years. High values may indicate sites where algae could be limiting coral recovery. Comparing this with coral cover helps identify sites where high algae coincides with low coral.

# %%
## Bar plot of observations per year

plt.figure(figsize=(8,5))
sns.countplot(x='YEAR', data=site_year_cover, palette='Blues')
plt.xlabel("Year")
plt.ylabel("Number of Site-Year Observations")
plt.title("Number of Observations per Year (Sampling Consistency)")
plt.show()

# %% [markdown]
# Shows how many site-year surveys were conducted each year. Even bars indicate consistent sampling, while uneven bars reveal gaps that could bias trend analysis. This tells us which years have stronger or weaker data for assessing recovery trajectories.

# %% [markdown]
# ### Section 2 of EDA - Temporal Trends (Recovery Trajectories)
#
# This analysis examines how coral cover has changed over time across reef sites. By analyzing yearly averages of coral cover, we can observe whether coral reefs are recovering after bleaching events or continuing to decline.
#
# Understanding these trends helps identify whether reef ecosystems are resilient to thermal stress or if long-term degradation is occurring.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('site_year_thermal_cover_FINAL.csv')

year_avg = df.groupby('YEAR')['total_cover'].mean()

plt.figure(figsize=(8,5))
plt.plot(year_avg.index, year_avg.values)

plt.title('Average Coral Cover Over Time')
plt.xlabel('Year')
plt.ylabel('Mean Coral Cover (%)')

plt.show()

# %% [markdown]
# This plot shows the average coral cover across all reef sites over time. Coral cover appears to decline around 2016 and then slightly increase by 2020. This trend may reflect the impact of thermal stress events such as coral bleaching, followed by partial recovery in some reef ecosystems.

# %% [markdown]
# ### Comparing Coral Cover Distributions
#
# To better understand reef recovery patterns, we compare the distribution of coral cover between two different years: 2016 and 2020.
#
# Histograms allow us to observe whether coral cover values are shifting toward higher or lower percentages over time.
# If coral cover increases in later years, this may suggest recovery after bleaching events.
# However, if coral cover remains low or declines, it may indicate continued ecological stress.

# %%
coral_2016 = df[df['YEAR'] == 2016]['total_cover']
coral_2020 = df[df['YEAR'] == 2020]['total_cover']

plt.figure(figsize=(8,5))

plt.hist(coral_2016, binwidth=2, alpha=0.5, label='2016')
plt.hist(coral_2020, binwidth=2, alpha=0.5, label='2020')

plt.xlabel('Coral Cover (%)')
plt.ylabel('Frequency')
plt.title('Distribution of Coral Cover: 2016 vs 2020')

plt.legend()
plt.show()

# %% [markdown]
# This histogram compares coral cover distributions between 2016 and 2020. The 2020 distribution appears slightly more concentrated around moderate coral cover values, which may indicate stabilization or early recovery in reef areas following thermal stress events. Some unusually high coral cover values appear in the dataset, likely due to measurement aggregation or methodological differences across sampling units.

# %% [markdown]
# ### Section 3 of EDA - Coral vs Algae Relationships
#
# Tasks:
#
# * Coral vs Algae Relationships
# * Explore ecological competition patterns
#
# Scatterplots:
# * Coral cover vs algae cover
#
# Correlation analysis
# * Heatmap: Coral cover, algae cover vs year
#
# Boxplots:
# * algae cover at low coral sites
# * algae cover at high coral sites
# * Shows whether degraded reefs are algae-dominated
#
# Interpret and document:
# * Is higher algae associated with lower coral?
# * Do reefs with high algae fail to recover?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("data/01-interim/site_year_cover.csv")
print(df.head())

# %%
#SCATTERPLOT
#Coral cover vs. Algae cover

plt.figure()
plt.scatter(df['total_coral_cover'], df['total_algae_cover'], color='#BA3F8F')
plt.xlabel("Coral Cover %")
plt.ylabel("Algae Cover %")
plt.title("Coral Cover vs. Algae Cover")
plt.show()

# %%
correlation_matrix = df[['total_coral_cover', 'total_algae_cover']].corr()
print("\nCorrelation matrix:")
print(correlation_matrix)

# %%
#BOXPLOTS
#Coral & algae cover by year

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Coral cover by year
sns.boxplot(data=df, x='YEAR', y='total_coral_cover', ax=axes[0], color='#E8735A')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Coral Cover (%)')
axes[0].set_title('Coral Cover by Year')

# Algae cover by year
sns.boxplot(data=df, x='YEAR', y='total_algae_cover', ax=axes[1], color='#3A7D44')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Algae Cover (%)')
axes[1].set_title('Algae Cover by Year')

plt.suptitle('Coral and Algae Cover Distribution by Year', fontsize=13)
plt.tight_layout()
plt.show()

# %%
#BOXPLOTS
#Algae cover at low vs high coral sites

low_threshold = 5       # "Low coral" = degraded reefs
high_threshold = 20     # "High coral" = healthy reefs

# Subset algae cover for each category

low_coral_algae = df[df['total_coral_cover'] < low_threshold]['total_algae_cover']
# Pull algae values ONLY from rows where coral is below the low threshold

high_coral_algae = df[df['total_coral_cover'] > high_threshold]['total_algae_cover']
# Pull algae values ONLY from rows where coral is above the high threshold

# Create a side-by-side boxplot comparing algae at low vs high coral sites

plt.figure(figsize=(8, 5))  # Make it wider
colors = ['#FF7E5F', '#FEB47B']  # sunset colors

plt.boxplot(
    [low_coral_algae, high_coral_algae],
    labels=['Low Coral Sites', 'High Coral Sites'],
    patch_artist=True,                         # allow colored boxes
    boxprops=dict(facecolor=colors[0], alpha=0.7),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', markersize=3, alpha=0.3)  # faint outliers
)
#for readability + aesthetic^^

plt.ylabel("Algae Cover (%)")
plt.title("Algae Levels at Low vs High Coral Sites")
plt.grid(axis='y', alpha=0.3)
plt.show()

# Summary statistics for documentation
print("\nAlgae cover at low coral sites:")
print(low_coral_algae.describe())

print("\nAlgae cover at high coral sites:")
print(high_coral_algae.describe())

# %%
#ANALYSIS

# Question 1: Is higher algae associated with lower coral?
if correlation_matrix.loc['total_coral_cover', 'total_algae_cover'] < 0:
    print("\nInterpretation: Higher algae is associated with lower coral cover.")
else:
    print("\nInterpretation: No strong evidence that high algae reduces coral in this dataset.")

# Question 2: Do reefs with high algae fail to recover?
print("\nCheck the heatmap and boxplots to assess temporal patterns and algae dominance at degraded sites.")

# %% [markdown]
# #### FINAL Interpretation:
#
# **Q1**: Correlation between algae and coral is weak, so the dataset does not show a strong direct inverse relationship.
# **Q2**: However, sites that already have high algae tend to remain coral-poor over time, suggesting limited recovery.
#
# This pattern is visible in the heatmap and boxplots even if the correlation alone is inconclusive.

# %% [markdown]
# ### Section 4 of EDA - Spatial Patterns
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data/01-interim/site_year_thermal_cover.csv')

sns.set(style="whitegrid")

# %%
plt.figure(figsize=(16,9))


sns.scatterplot(
    df,
    x = "longitude",
    y = "latitude",
    hue = "total_coral_cover",
    palette = "flare"
)

plt.title("Site Map by Coral Cover")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(title = "Coral Cover (%)", bbox_to_anchor=(1.05,1))
plt.show()

# %% [markdown]
# Coral is generally low across the two regions, showing low coral spread acorss Florida and USVI. This matches the previous observations in data.

# %%
plt.figure(figsize=(16,9))

sns.scatterplot(
    df,
    x = "longitude",
    y = "latitude",
    hue = "total_algae_cover",
    palette = "crest"
)

plt.title("Site Map by Algae Cover")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(title = "Algae Cover (%)", bbox_to_anchor=(1.05,1))
plt.show()

# %% [markdown]
# Algae cover distribution is also on the lower end, with the distributions being mainly within the lower 0-20% range.

# %%
plt.figure(figsize=(16,6))

sns.boxplot(
    df,
    x = "REGION",
    y = "total_coral_cover",
)

plt.xticks(rotation=45)
plt.title("Regional Coral Cover Comparison")
plt.xlabel("Region")
plt.ylabel("Coral Cover (%)")
plt.show()

# %% [markdown]
# Boxes indicate 25 to 75 percentile of coverage, while the dots beyond the whiskers represent outliers to the data.

# %%
regional_mean = (df.groupby(["YEAR", "REGION"])["total_coral_cover"].mean().reset_index())

plt.figure(figsize=(16,9))

sns.lineplot(
    regional_mean,
    x = "YEAR",
    y = "total_coral_cover",
    hue = "REGION",
    marker = "o"
)

plt.title("Regional Coral Cover Trends Over Time")
plt.xlabel("Year")
plt.ylabel("Mean Coral Cover (%)")
plt.legend(title = "Region", bbox_to_anchor=(1.05,1))
plt.show()

# %% [markdown]
# Most regions were increasing, but have seen decline over the past few years, with the exception of FLK (Florida). SEFCRI (Flordia) has been declining but showed increase after a dip in 2020-2022.

# %% [markdown]
# Some regions do appear to recover better, with the USVI regions (STTSTJ, STX) showing a more consistent recovery and trend than the Florida regions (FLK, SEFCRI).

# %% [markdown]
# Degraded reefs seem to be clustered.
#
# When one region in the USVI decreases, the other one seems to as well, which indicates a relationship between the two regions. This is probably because the proximity allows for diseases or other reasons for coral loss to transfer relatively easily.
#
# You can also see this pattern in the Flordia reefs (SEFRCI, FLK), in which they both decrease and increase at the same points.

# %% [markdown]
# ### Section 5 of EDA - Thermal Stress Prep

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)

merged = pd.read_csv('data/01-interim/site_year_thermal_cover.csv')

# %% [markdown]
# #### DHW Distribution

# %%
analysis_data = merged.copy()

# %%
print("\nDHW Summary Statistics (All three years):")
print(f"  Mean: {analysis_data['annual_dhw'].mean():.2f}°C-weeks")
print(f"  Median: {analysis_data['annual_dhw'].median():.2f}°C-weeks")
print(f"  Std Dev: {analysis_data['annual_dhw'].std():.2f}°C-weeks")
print(f"  Range: {analysis_data['annual_dhw'].min():.2f} - {analysis_data['annual_dhw'].max():.2f}°C-weeks")

# %%
print("\nDHW by Year:")
year_stats = []
for year in sorted(analysis_data['YEAR'].unique()):
    year_data = analysis_data[analysis_data['YEAR'] == year]['annual_dhw']
    print(f"  {int(year)}: n={len(year_data)}, mean={year_data.mean():.2f}, median={year_data.median():.2f}, max={year_data.max():.2f}")

# %% [markdown]
# This raises some data quality concerns for the year 2020. We will try another merge with using raw benthic data and aggregating by site-year first hoping to solve the 2020 data extraction problem.

# %%
from sklearn.neighbors import BallTree

# %%
florida_benthic = pd.read_csv("data/02-processed/benthic_cover_FL_cleaned.csv")
puerto_rico_benthic = pd.read_csv("data/02-processed/benthic_cover_PR_cleaned.csv")
usvi_benthic = pd.read_csv("data/02-processed/benthic_cover_USVI_cleaned.csv")

# combining all the raw files for the regions
benthic_all = pd.concat([florida_benthic, puerto_rico_benthic, usvi_benthic], ignore_index=True)

# %%
thermal_data = pd.read_csv('data/00-raw/thermal_caribbean_2016_2018_2020_PROCESSED.csv')

print(f"\nBenthic data: {len(benthic_all)} rows")
print(f"Thermal data: {len(thermal_data)} rows")

# %%
print(f"Florida unique years : {florida_benthic['YEAR'].unique()}")

# %%
print(f"Puerto Rico unique years : {puerto_rico_benthic['YEAR'].unique()}")

# %%
print(f"USVI unique years : {usvi_benthic['YEAR'].unique()}")

# %% [markdown]
# #### Available data for analysis

# %%
benthic_clean = benthic_all.dropna(subset=['YEAR']).copy()
benthic_clean['YEAR'] = benthic_clean['YEAR'].astype(int)
thermal_clean = thermal_data.copy()
thermal_clean['year'] = thermal_clean['year'].astype(int)


print(f"\nBenthic data years: {sorted(benthic_clean['YEAR'].unique())}")


print(f"Thermal data years: {sorted(thermal_clean['year'].unique())}")

# Years with both kinds of data
years_both = set(benthic_clean['YEAR'].unique()) & set(thermal_clean['year'].unique())
print(f"Years with BOTH benthic + thermal: {sorted(years_both)}")

# No. of sites per year
print(f"\nBenthic sites by year:")
for year in sorted(benthic_clean['YEAR'].unique()):
    count = (benthic_clean['YEAR'] == year).sum()
    print(f"  {int(year)}: {count}")

# %% [markdown]
# Since we have both thermal and benthic data for 2016, 2018 and 2020, we know that we do have valid data for the year of 2020. We will now re-merge the benthic and thermal datasets with a distance threshold.

# %% [markdown]
# #### Re-merging 2016, 2018, 2020 with distance threshold

# %%
benthic_all = benthic_all.dropna(subset=['YEAR'])
benthic_all['YEAR'] = benthic_all['YEAR'].astype(int)

years_to_use = [2016, 2018, 2020]
benthic_all = benthic_all[benthic_all['YEAR'].isin(years_to_use)]
print(f" Benthic data : {len(benthic_all)} rows")

# %% [markdown]
# Aggregate benthic data to site-year

# %%
site_year_benthic = benthic_all.groupby(['PRIMARY_SAMPLE_UNIT', 'YEAR', 'latitude', 'longitude', 'REGION']).agg({
    'HARDBOTTOM_P': 'sum'
}).reset_index()

site_year_benthic.columns = ['PRIMARY_SAMPLE_UNIT', 'YEAR', 'latitude', 'longitude', 'REGION', 'total_cover']
print(f"Aggregated to {len(site_year_benthic)} site-year observations")
print(site_year_benthic.head() )

# %%
thermal_data['year'] = thermal_data['year'].astype(int)
thermal_data = thermal_data[thermal_data['year'].isin(years_to_use)]
print(f"Thermal data loaded: {len(thermal_data)} rows")

# Converting coordinates to numeric and clean
print("\nSTEP 4: Cleaning coordinates...")
site_year_benthic['latitude'] = pd.to_numeric(site_year_benthic['latitude'], errors='coerce')
site_year_benthic['longitude'] = pd.to_numeric(site_year_benthic['longitude'], errors='coerce')
thermal_data['latitude'] = pd.to_numeric(thermal_data['latitude'], errors='coerce')
thermal_data['longitude'] = pd.to_numeric(thermal_data['longitude'], errors='coerce')

site_year_benthic = site_year_benthic.dropna(subset=['latitude', 'longitude'])
thermal_data = thermal_data.dropna(subset=['latitude', 'longitude'])
print(f" After cleaning: {len(site_year_benthic)} benthic, {len(thermal_data)} thermal")

# Merging by year with distance threshold
print("\nSTEP 5: Merging benthic + thermal data...")
merged_results = []

for year in sorted(years_to_use):
    benthic_year = site_year_benthic[site_year_benthic['YEAR'] == year].copy()
    thermal_year = thermal_data[thermal_data['year'] == year].copy()
    
    print(f"\n  {int(year)}:")
    print(f"    Benthic sites: {len(benthic_year)}")
    print(f"    Thermal grid points: {len(thermal_year)}")
    
    # Building BallTree
    thermal_coords_rad = np.radians(thermal_year[['latitude', 'longitude']].values)
    tree = BallTree(thermal_coords_rad, metric='haversine')
    
    # Nearest neighbor
    benthic_coords_rad = np.radians(benthic_year[['latitude', 'longitude']].values)
    distances, indices = tree.query(benthic_coords_rad, k=1)
    
    # Converting to km
    distances_km = distances.flatten() * 6371
    
    # Distance threshold = 5 km 
    distance_threshold = 5.0
    valid_matches = distances_km <= distance_threshold
    
    print(f"    Matches within {distance_threshold}km: {valid_matches.sum()} / {len(benthic_year)} ({valid_matches.sum()/len(benthic_year)*100:.1f}%)")
    print(f"    Distance stats: mean={distances_km.mean():.2f}km, max={distances_km.max():.2f}km")
    
    # Getting valid matches
    valid_indices = np.where(valid_matches)[0]
    valid_thermal_indices = indices.flatten()[valid_matches]
    
    benthic_year_valid = benthic_year.iloc[valid_indices].copy()
    thermal_year_subset = thermal_year.iloc[valid_thermal_indices].copy()
    
    benthic_year_valid['annual_dhw'] = thermal_year_subset['annual_dhw'].values
    benthic_year_valid['distance_to_thermal_km'] = distances_km[valid_matches]
    
    dhw_stats = benthic_year_valid['annual_dhw']
    print(f"    DHW stats: mean={dhw_stats.mean():.2f}°C-weeks, max={dhw_stats.max():.2f}°C-weeks")
    
    merged_results.append(benthic_year_valid)

# %% [markdown]
# #### Final dataset

# %%
# Combining all years
merged_final = pd.concat(merged_results, ignore_index=True)

print("FINAL DATASET SUMMARY")
print(f"\nTotal rows: {len(merged_final)}")

print(f"\nRows by year:")
for year in sorted(merged_final['YEAR'].unique()):
    count = (merged_final['YEAR'] == year).sum()
    print(f"  {int(year)}: {count}")

print(f"\nDHW by year:")
for year in sorted(merged_final['YEAR'].unique()):
    year_dhw = merged_final[merged_final['YEAR'] == year]['annual_dhw']
    print(f"  {int(year)}: mean={year_dhw.mean():.2f}°C-weeks, max={year_dhw.max():.2f}°C-weeks")


merged_final.to_csv('site_year_thermal_cover_FINAL.csv', index=False)

print(f"\nSample of final merged data:")
print(merged_final[['PRIMARY_SAMPLE_UNIT', 'YEAR', 'latitude', 'longitude', 'total_cover', 'annual_dhw']].head(10))

# %% [markdown]
# ### Thermal data EDA

# %%
merged_final = pd.read_csv('site_year_thermal_cover_FINAL.csv')

print(f"Final dataset loaded: {merged_final.shape}")
print(f"Columns: {list(merged_final.columns)}")
print(f"\nFirst few rows:")
print(merged_final.head())

# %% [markdown]
# #### DHW Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)


print("\nDHW Summary Statistics (All years combined):")
print(f"  Mean: {merged_final['annual_dhw'].mean():.2f}°C-weeks")
print(f"  Median: {merged_final['annual_dhw'].median():.2f}°C-weeks")
print(f"  Std Dev: {merged_final['annual_dhw'].std():.2f}°C-weeks")
print(f"  Range: {merged_final['annual_dhw'].min():.2f} - {merged_final['annual_dhw'].max():.2f}°C-weeks")


print("\nDHW by Year:")
for year in sorted(merged_final['YEAR'].unique()):
    year_data = merged_final[merged_final['YEAR'] == year]['annual_dhw']
    print(f"  {int(year)}: n={len(year_data)}, mean={year_data.mean():.2f}, median={year_data.median():.2f}, max={year_data.max():.2f}")


bleach_threshold = 4
bleach_count = (merged_final['annual_dhw'] >= bleach_threshold).sum()
bleach_pct = bleach_count / len(merged_final) * 100
print(f"\nBleaching-level stress (DHW ≥ {bleach_threshold}°C-weeks):")
print(f"  Sites: {bleach_count} / {len(merged_final)} ({bleach_pct:.1f}%)")


fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Overall distribution
ax1 = axes[0]
ax1.hist(merged_final['annual_dhw'], bins=40, color='coral', edgecolor='black', alpha=0.7)
ax1.axvline(bleach_threshold, color='red', linestyle='--', linewidth=2, label=f'Bleach threshold (≥{bleach_threshold}°C-weeks)')
ax1.axvline(merged_final['annual_dhw'].mean(), color='blue', linestyle='--', linewidth=2, label=f'Mean ({merged_final["annual_dhw"].mean():.2f})')
ax1.set_xlabel('Annual Maximum DHW (°C-weeks)', fontsize=12)
ax1.set_ylabel('Frequency (number of sites)', fontsize=12)
ax1.set_title('Distribution of Thermal Stress\n(All years combined, n=875)', fontsize=13, fontweight='bold')
ax1.legend()
ax1.grid(True, alpha=0.3)

# By year
ax2 = axes[1]
colors = ['#d62728', '#ff7f0e', '#2ca02c']
for year, color in zip(sorted(merged_final['YEAR'].unique()), colors):
    year_data = merged_final[merged_final['YEAR'] == year]['annual_dhw']
    ax2.hist(year_data, bins=30, alpha=0.5, label=f'{int(year)} (n={len(year_data)}, mean={year_data.mean():.2f})', 
             edgecolor='black', color=color)
ax2.axvline(bleach_threshold, color='red', linestyle='--', linewidth=2, label='Bleach threshold')
ax2.set_xlabel('Annual Maximum DHW (°C-weeks)', fontsize=12)
ax2.set_ylabel('Frequency (number of sites)', fontsize=12)
ax2.set_title('DHW Distribution by Year\n(2016 bleaching year vs recovery)', fontsize=13, fontweight='bold')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('01_dhw_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Here, even after careful extraction of data and merging, we still seem to have anomalously low DHW values for 2020 with a mean of 0.00 and a max of 0.15 °C-weeks. This contradicts the documented severe bleaching event in 2020 across the world. This could be a data extraction or geographical sampling issue. Therefore, moving foward we will interpret results related to the year 2020 very carefully.

# %% [markdown]
# #### Coral Cover vs Thermal Stress

# %%
print("\nCoral Cover Statistics:")
print(f"  Mean coral: {merged_final['total_cover'].mean():.2f}%")
print(f"  Median coral: {merged_final['total_cover'].median():.2f}%")
print(f"  Range: {merged_final['total_cover'].min():.2f} - {merged_final['total_cover'].max():.2f}%")

# By stress level
low_stress = merged_final[merged_final['annual_dhw'] < 4]
high_stress = merged_final[merged_final['annual_dhw'] >= 4]

print(f"\nCoral by stress level:")
print(f"  Low stress (DHW < 4): n={len(low_stress)}, mean coral={low_stress['total_cover'].mean():.2f}%")
print(f"  High stress (DHW ≥ 4): n={len(high_stress)}, mean coral={high_stress['total_cover'].mean():.2f}%")
print(f"  Difference: {high_stress['total_cover'].mean() - low_stress['total_cover'].mean():.2f}%")


correlation = merged_final['annual_dhw'].corr(merged_final['total_cover'])
print(f"\nPearson correlation (DHW vs coral): r = {correlation:.3f}")


fig, axes = plt.subplots(1, 2, figsize=(14, 5))


ax1 = axes[0]
stress_categories = ['Low stress\n(DHW < 4)', 'High stress\n(DHW ≥ 4)']
coral_by_stress = [low_stress['total_cover'].values, high_stress['total_cover'].values]

bp = ax1.boxplot(coral_by_stress, labels=stress_categories, patch_artist=True, widths=0.6)
for patch, color in zip(bp['boxes'], ['lightgreen', 'lightcoral']):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

ax1.set_ylabel('Total Coral Cover (%)', fontsize=12)
ax1.set_title('Coral Cover by Thermal Stress Level\n(Bleaching threshold: DHW ≥ 4°C-weeks)', fontsize=13, fontweight='bold')
ax1.grid(True, alpha=0.3, axis='y')


ax2 = axes[1]
colors_by_year = {2016.0: '#d62728', 2018.0: '#ff7f0e', 2020.0: '#2ca02c'}
for year in sorted(merged_final['YEAR'].unique()):
    year_data = merged_final[merged_final['YEAR'] == year]
    ax2.scatter(year_data['annual_dhw'], year_data['total_cover'], 
               label=f'{int(year)} (n={len(year_data)})', 
               s=80, alpha=0.6, color=colors_by_year[year], edgecolors='black', linewidth=0.5)


z = np.polyfit(merged_final['annual_dhw'], merged_final['total_cover'], 1)
p = np.poly1d(z)
x_trend = np.linspace(merged_final['annual_dhw'].min(), merged_final['annual_dhw'].max(), 100)
ax2.plot(x_trend, p(x_trend), "k--", linewidth=2, label=f'Trend (r={correlation:.2f})')

ax2.axvline(4, color='red', linestyle='--', linewidth=1.5, alpha=0.5, label='Bleach threshold')
ax2.set_xlabel('Annual Maximum DHW (°C-weeks)', fontsize=12)
ax2.set_ylabel('Total Coral Cover (%)', fontsize=12)
ax2.set_title('Coral Cover vs Thermal Stress\n(Relationship test)', fontsize=13, fontweight='bold')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('02_coral_vs_dhw.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
from scipy.stats import pearsonr, ttest_ind
corr_coef, p_value = pearsonr(merged_final['annual_dhw'], merged_final['total_cover'])
print(f"\nStatistical significance:")
print(f"  Pearson r = {corr_coef:.3f}")
print(f"  p-value = {p_value:.4f}")
if p_value < 0.05:
    print(f" Significant relationship (p < 0.05)")
else:
    print(f" Not significant (p ≥ 0.05)")

# T-test between groups
t_stat, t_pval = ttest_ind(low_stress['total_cover'], high_stress['total_cover'])
print(f"\nT-test (Low vs High stress coral cover):")
print(f"  t-statistic = {t_stat:.3f}")
print(f"  p-value = {t_pval:.4f}")
if t_pval < 0.05:
    print(f" Significant difference between groups (p < 0.05)")
else:
    print(f" No significant difference (p ≥ 0.05)")

# %%
from scipy.stats import pearsonr
corr_coef, p_value = pearsonr(merged_final['annual_dhw'], merged_final['total_cover'])
print(f"Exact p-value: {p_value}")
print(f"p-value in scientific notation: {p_value:.2e}")

# %%
from scipy.stats import linregress

slope, intercept, r_value, p_value, std_err = linregress(merged_final['annual_dhw'], 
                                                           merged_final['total_cover'])

print(f"Regression equation: Coral Cover = {intercept:.2f} + {slope:.4f} × DHW")
print(f"Slope: {slope:.4f}")

# %% [markdown]
# Correlation Analysis:
# - Pearson correlation coefficient: r = -0.199
# - p-value: 3.05 × 10⁻⁹ (highly significant)
# This helps us conclude that as thermal stress increases, coral cover decreases.
#
# While the correlation is weak, the relationship is highly significant statistically. This means the pattern is real and not due to chance—even though other factors explain most of the variation.
#
# The negative correlation indicates that reef sites experiencing higher thermal stress tend to have lower coral cover. A 1°C-week increase in DHW is associated with approximately 0.07% decrease in coral cover (based on the regression slope).

# %% [markdown]
# #### Coral cover by year

# %%
for year in sorted(merged_final['YEAR'].unique()):
    year_data = merged_final[merged_final['YEAR'] == year]['total_cover']
    print(f"  {int(year)}: mean={year_data.mean():.2f}%, median={year_data.median():.2f}%, n={len(year_data)}")

# Calculating recovery rate
coral_2016 = merged_final[merged_final['YEAR'] == 2016]['total_cover'].mean()
coral_2018 = merged_final[merged_final['YEAR'] == 2018]['total_cover'].mean()
coral_2020 = merged_final[merged_final['YEAR'] == 2020]['total_cover'].mean()

print(f" Recovery trajectory:")
print(f"  2016 to 2018 change: {coral_2018 - coral_2016:.2f}% ({(coral_2018-coral_2016)/coral_2016*100:.1f}% per year)")
print(f"  2018 to 2020 change: {coral_2020 - coral_2018:.2f}% ({(coral_2020-coral_2018)/2/coral_2018*100:.1f}% per year)")
print(f"  2016 to 2020 change: {coral_2020 - coral_2016:.2f}% ({(coral_2020-coral_2016)/4/coral_2016*100:.1f}% per year)")


fig, ax = plt.subplots(figsize=(10, 6))

data_by_year = [merged_final[merged_final['YEAR'] == year]['total_cover'].values 
                 for year in sorted(merged_final['YEAR'].unique())]

bp = ax.boxplot(data_by_year, 
                labels=[f'{int(y)}' for y in sorted(merged_final['YEAR'].unique())],
                patch_artist=True,
                widths=0.6)

colors = ['#d62728', '#ff7f0e', '#2ca02c']
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.7)

ax.set_xlabel('Year', fontsize=12, fontweight='bold')
ax.set_ylabel('Total Coral Cover (%)', fontsize=12, fontweight='bold')
ax.set_title('Coral Cover Recovery Over Time\n(2016 bleaching year → 2020 recovery)', fontsize=13, fontweight='bold')
ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('03_coral_by_year.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# All three years show wide ranges in coral cover (0% to 400%), indicating substantial heterogeneity across reef sites. Some reefs maintained healthy coral coverage throughout the period while some other reefs had severely depleted coral cover.
#
# The median shows remarkable stability, suggesting no major shifts in typical reef condition.
# Many sites with near-zero coral cover appear as circles below the whiskers. These outliers are consistent across all three years which suggests that some reefs are chronically degraded and that this degradation is probablu unrelated to the 2016 bleaching event.
#
# Looking at the recovery trajectory, there is a lack of a clear upward recovery trend, which goes against our hypothesis of seeing a clear, albeit slow recovery pattern post bleaching. Recovery trajectories exist but do not have a clear pattern to them and are heterogeneous.
#
# Thermal stress varies substantially (0.90 -> 0.49 -> 0.00°C-weeks from 2016-2020), yet coral cover shows minimal change. This decoupling between thermal stress and recovery suggests that thermal stress alone does not determine recovery trajectory in these reefs.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > This project does not involve human subjects or individual-level data. All datasets used are publicly available environmental monitoring datasets collected by government agencies (e.g., NOAA) using standardized ecological survey methods.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Collection bias is relevant because coral reef monitoring sites are not evenly distributed across regions or reef types. Some U.S. reef systems may be monitored more frequently or consistently than others due to accessibility, funding, or conservation priority. This could bias observed recovery pathways toward better-studied regions. We acknowledge this limitation and will avoid overgeneralizing results beyond the monitored sites.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > This project does not collect or use any personally identifiable information. All data are ecological and site-level, such as percent coral cover and thermal stress metrics.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > Because this project does not involve human populations or protected groups, downstream bias related to demographic characteristics is not applicable
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > The datasets used are publicly available and contain no sensitive information. Data will be stored locally for analysis using standard file protections. While advanced security measures are not required, care will be taken to avoid accidental modification or loss of data.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > The project does not use personal or individual-level data. There are no individuals whose data could be removed upon request.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
# > Data will be retained only for the duration of the course project and may be deleted afterward. Since the data are publicly available, long-term storage does not pose ethical concerns.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > Our analysis does not include input from reef managers or local communities. Our findings *could* influence policy or funding, e.g., reefs with faster recovery might get more attention, while slower-recovering reefs could be deprioritized. We will clarify that recovery trajectories are descriptive, not value judgments.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Potential sources of bias include uneven temporal coverage across sites, missing years of data, and unmeasured confounding factors such as storms, pollution, or local management practices. These limitations may affect interpretation of recovery trajectories and will be discussed when presenting results.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > Visualizations and summary statistics will be designed to accurately reflect the underlying data, including showing uncertainty, missing data, and variability across sites. We will avoid visual choices that exaggerate trends or imply causation.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > No data with personally identifiable information will be used or displayed, as all data are ecological and environmental in nature.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > The data cleaning, merging, and analysis process will be documented using reproducible code and clear descriptions of methods. This allows the analysis to be reviewed or revisited if issues are discovered later.
#
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > This project does not involve predictive models that affect individuals, nor does it include demographic variables.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > Fairness across human groups is not applicable. However, we recognize that modeling choices may implicitly emphasize certain regions or reef types over others due to data availability.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > Recovery metrics such as changes in percent live coral cover or trajectory slopes were chosen because they are commonly used in reef ecology. We acknowledge that no single metric fully captures reef health and will discuss this limitation.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > The analytical methods used are interpretable and can be explained in clear terms. We will avoid complex models that obscure interpretation.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > Limitations such as observational data, lack of causal inference, and incomplete coverage will be clearly communicated in the final report to avoid misinterpretation of results.
#
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > This project is exploratory and academic in nature and will not be deployed in a production environment. Ongoing monitoring is therefore not applicable.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > Because this analysis does not produce decisions affecting individuals or communities directly, formal redress mechanisms are not required. However, we aim to present findings responsibly to avoid misuse.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# > There is no deployed system or model to roll back. If errors are discovered, analyses and conclusions can be revised.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > While the project is academic, results could potentially be misused if interpreted as causal or definitive. To mitigate this, we will clearly state the scope, assumptions, and limitations of the analysis.

# %% [markdown]
# ## Discusison and Conclusion
# ---

# %% [markdown]
# This project examined coral reef recovery across U.S. Caribbean reef sites in Florida, Puerto Rico, and the U.S. Virgin Islands during the four years following the 2016 mass bleaching event. Using NOAA's National Coral Reef Monitoring Program benthic survey data together with NOAA Coral Reef Watch thermal stress data, we built a site-year dataset tracking percent coral and algae cover for 2016, 2018, and 2020. Our goal was to see **whether different recovery trajectories emerged across sites**, and **whether cumulative thermal stress** (measured as Degree Heating Weeks) **and baseline algal cover were associated with those outcomes**. Understanding what drives differences in reef recovery is important because it can help conservation efforts identify which sites may be most vulnerable to long-term degradation.

# %% [markdown]
# Recovery patterns across sites varied quite a bit. Some reefs showed clear gains in coral cover between 2016 and 2020, while others declined or stayed about the same. Interestingly, at the same time, the median coral cover remained fairly stable across all three years, suggesting that the typical reef site did not experience a major long-term shift after the 2016 bleaching event. However, this overall stability *hides a lot of variation between locations*. Sites with near-zero coral cover stayed consistently degraded across all three years, suggesting ongoing decline at some reefs that is likely not driven by the 2016 event alone. Looking at geography, reefs in the USVI regions showed more consistent recovery patterns than those in Florida. Degraded reefs also seemed to cluster geographically; when one USVI region declined, the other often did as well. This pattern may reflect shared exposure to regional stressors such as disease outbreaks or temperature patterns.

# %% [markdown]
# Our thermal stress analysis partially supported our hypothesis. We found a statistically significant negative relationship between annual DHW and coral cover (Pearson r = -0.199, p = 3.05 × 10⁻⁹), meaning sites that experienced *higher thermal stress generally had lower coral cover*. This result aligns with Hughes et al. (2017), who found that higher cumulative thermal stress during the 2016 bleaching event directly drove coral mortality across the Indo-Pacific. While our results extend that finding to the recover phase, the effect size was relatively small, suggesting that thermal stress alone explains only a limited portion of the variation in coral cover across sites. One data limitation affects this part of the analysis: 2020 DHW values in our dataset were unexpectedly low (mean of 0.00°C-weeks, max of 0.15°C-weeks), which conflicts with documented thermal stress events that year. This likely reflects a data extraction or spatial matching issue rather than actual ecological conditions, meaning our conclusions about the 2018–2020 recovery period should be interpreted cautiously.

# %% [markdown]
# The relationship between algal cover and coral recovery also supported our hypothesis, *though again with a modest effect*. Sites with higher baseline algae cover during the 2016 bleaching event tended to show weaker coral recovery over the following four years. This makes ecological sense, since algae and coral compete for space on the reef substrate. When algae become dominant after a disturbance, they can prevent coral larvae from settling and forming new colonies. The boxplot analysis from Section 3 supports this pattern, showing that low-coral sites generally had higher algae cover than high-coral sites. Taken together, the results suggest that both thermal stress and algal dominance contribute to weaker recovery outcomes, though neither factor alone strongly predicts reef condition. This aligns with the broader ecological understanding that reef degradation is driven by multiple interacting stressors.

# %% [markdown]
# ***Several limitations of this study should also be considered***. Monitoring sites in the NCRMP dataset were not randomly selected; they tend to reflect locationthat are easier to access or scientifically prioritized, which means our sample may not fully represent all Caribbean reef environments. In addition, the benthic cover data combines many coral and algae species into single categories, which removes species-level detail that could reveal more detailed recovery patterns. Possibly most importantly, our analysis could not account for other important factors such as storm damage, fishing pressure, sedimentation, disease outbreaks, or local water quality, which are known to influence reef health and vary across sites. Future research could incorporate these variables and extend the analysis beyond 2020 to better understand whether reefs eventually recover or continue to decline. Despite these limitations, our analysis highlights clear spatial and temporal differences in Caribbean reef recovery and suggests that effective conservation strategies will likely need to be tailored to individual reef systems rather than assuming uniform responses to bleaching events.
